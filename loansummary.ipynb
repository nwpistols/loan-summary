# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from mortgage import Mortgage
from mortgage import _style
from mortgage import table_multiple_down_payment_percents, table_multiple_interest_rates

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Compare Multiple Mortgages

# %% [markdown]
# ## Multiple down payment percentages

# %%
table, list_mortgages = table_multiple_down_payment_percents(
    sale_price=750000, 
    down_payment_percents=[5,10,15,20,25,30], 
    interest_rate=0.0275,
)
table
# Out:
# <style type="text/css">
# #T_edc6e_ tbody {
#   border: solid thin #ddd;
# }
# #T_edc6e_ thead {
#   border: solid thin #ddd;
# }
# #T_edc6e_row0_col0, #T_edc6e_row1_col0, #T_edc6e_row1_col1, #T_edc6e_row1_col2, #T_edc6e_row1_col3, #T_edc6e_row1_col4, #T_edc6e_row1_col5, #T_edc6e_row2_col0, #T_edc6e_row2_col1, #T_edc6e_row2_col2, #T_edc6e_row2_col3, #T_edc6e_row2_col4, #T_edc6e_row2_col5, #T_edc6e_row3_col0, #T_edc6e_row3_col1, #T_edc6e_row3_col2, #T_edc6e_row3_col3, #T_edc6e_row3_col4, #T_edc6e_row3_col5, #T_edc6e_row4_col0, #T_edc6e_row5_col5, #T_edc6e_row6_col0, #T_edc6e_row6_col1, #T_edc6e_row6_col2, #T_edc6e_row6_col3, #T_edc6e_row6_col4, #T_edc6e_row6_col5, #T_edc6e_row7_col3, #T_edc6e_row7_col4, #T_edc6e_row7_col5, #T_edc6e_row8_col5, #T_edc6e_row9_col5, #T_edc6e_row10_col5, #T_edc6e_row11_col0, #T_edc6e_row11_col1, #T_edc6e_row11_col2, #T_edc6e_row11_col3, #T_edc6e_row11_col4, #T_edc6e_row11_col5, #T_edc6e_row12_col5, #T_edc6e_row13_col5, #T_edc6e_row14_col3, #T_edc6e_row14_col4, #T_edc6e_row14_col5, #T_edc6e_row15_col5, #T_edc6e_row16_col5 {
#   font-weight: bold;
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_edc6e_row0_col1, #T_edc6e_row4_col1, #T_edc6e_row5_col4, #T_edc6e_row8_col4, #T_edc6e_row12_col4, #T_edc6e_row13_col4 {
#   font-weight: bold;
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_edc6e_row0_col2, #T_edc6e_row4_col2, #T_edc6e_row5_col3, #T_edc6e_row8_col3, #T_edc6e_row12_col3, #T_edc6e_row13_col3 {
#   font-weight: bold;
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_edc6e_row0_col3, #T_edc6e_row4_col3, #T_edc6e_row5_col2, #T_edc6e_row8_col2, #T_edc6e_row12_col2, #T_edc6e_row13_col2 {
#   font-weight: bold;
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_edc6e_row0_col4, #T_edc6e_row4_col4, #T_edc6e_row5_col1, #T_edc6e_row8_col1, #T_edc6e_row12_col1, #T_edc6e_row13_col1 {
#   font-weight: bold;
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_edc6e_row0_col5, #T_edc6e_row4_col5, #T_edc6e_row5_col0, #T_edc6e_row7_col0, #T_edc6e_row8_col0, #T_edc6e_row9_col0, #T_edc6e_row10_col0, #T_edc6e_row12_col0, #T_edc6e_row13_col0, #T_edc6e_row14_col0, #T_edc6e_row15_col0, #T_edc6e_row16_col0 {
#   font-weight: bold;
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_edc6e_row7_col1, #T_edc6e_row14_col1 {
#   font-weight: bold;
#   background-color: #800610;
#   color: #f1f1f1;
# }
# #T_edc6e_row7_col2, #T_edc6e_row14_col2 {
#   font-weight: bold;
#   background-color: #9a0c14;
#   color: #f1f1f1;
# }
# #T_edc6e_row9_col1, #T_edc6e_row10_col1 {
#   font-weight: bold;
#   background-color: #af1117;
#   color: #f1f1f1;
# }
# #T_edc6e_row9_col2, #T_edc6e_row10_col2 {
#   font-weight: bold;
#   background-color: #de2b25;
#   color: #f1f1f1;
# }
# #T_edc6e_row9_col3, #T_edc6e_row10_col3 {
#   font-weight: bold;
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_edc6e_row9_col4, #T_edc6e_row10_col4 {
#   font-weight: bold;
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_edc6e_row15_col1, #T_edc6e_row16_col1 {
#   font-weight: bold;
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_edc6e_row15_col2, #T_edc6e_row16_col2 {
#   font-weight: bold;
#   background-color: #e12d26;
#   color: #f1f1f1;
# }
# #T_edc6e_row15_col3, #T_edc6e_row16_col3 {
#   font-weight: bold;
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_edc6e_row15_col4, #T_edc6e_row16_col4 {
#   font-weight: bold;
#   background-color: #fed9c9;
#   color: #000000;
# }
# </style>
# <table id="T_edc6e_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Down Payment Rate</th>
#       <th class="col_heading level0 col0" >5.0%</th>
#       <th class="col_heading level0 col1" >10.0%</th>
#       <th class="col_heading level0 col2" >15.0%</th>
#       <th class="col_heading level0 col3" >20.0%</th>
#       <th class="col_heading level0 col4" >25.0%</th>
#       <th class="col_heading level0 col5" >30.0%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edc6e_level0_row0" class="row_heading level0 row0" >Down Payment Fraction</th>
#       <td id="T_edc6e_row0_col0" class="data row0 col0" >0.050000</td>
#       <td id="T_edc6e_row0_col1" class="data row0 col1" >0.100000</td>
#       <td id="T_edc6e_row0_col2" class="data row0 col2" >0.150000</td>
#       <td id="T_edc6e_row0_col3" class="data row0 col3" >0.200000</td>
#       <td id="T_edc6e_row0_col4" class="data row0 col4" >0.250000</td>
#       <td id="T_edc6e_row0_col5" class="data row0 col5" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_edc6e_level0_row1" class="row_heading level0 row1" >Interest Rate</th>
#       <td id="T_edc6e_row1_col0" class="data row1 col0" >0.027500</td>
#       <td id="T_edc6e_row1_col1" class="data row1 col1" >0.027500</td>
#       <td id="T_edc6e_row1_col2" class="data row1 col2" >0.027500</td>
#       <td id="T_edc6e_row1_col3" class="data row1 col3" >0.027500</td>
#       <td id="T_edc6e_row1_col4" class="data row1 col4" >0.027500</td>
#       <td id="T_edc6e_row1_col5" class="data row1 col5" >0.027500</td>
#     </tr>
#     <tr>
#       <th id="T_edc6e_level0_row2" class="row_heading level0 row2" >PMI Rate</th>
#       <td id="T_edc6e_row2_col0" class="data row2 col0" >0.5%</td>
#       <td id="T_edc6e_row2_col1" class="data row2 col1" >0.5%</td>
#       <td id="T_edc6e_row2_col2" class="data row2 col2" >0.5%</td>
#       <td id="T_edc6e_row2_col3" class="data row2 col3" >0.5%</td>
#       <td id="T_edc6e_row2_col4" class="data row2 col4" >0.5%</td>
#       <td id="T_edc6e_row2_col5" class="data row2 col5" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_edc6e_level0_row3" class="row_heading level0 row3" >Sale Price</th>
#       <td id="T_edc6e_row3_col0" class="data row3 col0" >$750,000</td>
#       <td id="T_edc6e_row3_col1" class="data row3 col1" >$750,000</td>
#       <td id="T_edc6e_row3_col2" class="data row3 col2" >$750,000</td>
#       <td id="T_edc6e_row3_col3" class="data row3 col3" >$750,000</td>
#       <td id="T_edc6e_row3_col4" class="data row3 col4" >$750,000</td>
#       <td id="T_edc6e_row3_col5" class="data row3 col5" >$750,000</td>
#     </tr>
#     <tr>
#       <th id="T_edc6e_level0_row4" class="row_heading level0 row4" >Down Payment</th>
#       <td id="T_edc6e_row4_col0" class="data row4 col0" >$37,500</td>
#       <td id="T_edc6e_row4_col1" class="data row4 col1" >$75,000</td>
#       <td id="T_edc6e_row4_col2" class="data row4 col2" >$112,500</td>
#       <td id="T_edc6e_row4_col3" class="data row4 col3" >$150,000</td>
#       <td id="T_edc6e_row4_col4" class="data row4 col4" >$187,500</td>
#       <td id="T_edc6e_row4_col5" class="data row4 col5" >$225,000</td>
#     </tr>
#     <tr>
#       <th id="T_edc6e_level0_row5" class="row_heading level0 row5" >Principal loan</th>
#       <td id="T_edc6e_row5_col0" class="data row5 col0" >$712,500</td>
#       <td id="T_edc6e_row5_col1" class="data row5 col1" >$675,000</td>
#       <td id="T_edc6e_row5_col2" class="data row5 col2" >$637,500</td>
#       <td id="T_edc6e_row5_col3" class="data row5 col3" >$600,000</td>
#       <td id="T_edc6e_row5_col4" class="data row5 col4" >$562,500</td>
#       <td id="T_edc6e_row5_col5" class="data row5 col5" >$525,000</td>
#     </tr>
#     <tr>
#       <th id="T_edc6e_level0_row6" class="row_heading level0 row6" >Interest to Principal Ratio</th>
#       <td id="T_edc6e_row6_col0" class="data row6 col0" >0.470</td>
#       <td id="T_edc6e_row6_col1" class="data row6 col1" >0.470</td>
#       <td id="T_edc6e_row6_col2" class="data row6 col2" >0.470</td>
#       <td id="T_edc6e_row6_col3" class="data row6 col3" >0.470</td>
#       <td id="T_edc6e_row6_col4" class="data row6 col4" >0.470</td>
#       <td id="T_edc6e_row6_col5" class="data row6 col5" >0.470</td>
#     </tr>
#     <tr>
#       <th id="T_edc6e_level0_row7" class="row_heading level0 row7" >Monthly PMI Insurance</th>
#       <td id="T_edc6e_row7_col0" class="data row7 col0" >$297</td>
#       <td id="T_edc6e_row7_col1" class="data row7 col1" >$281</td>
#       <td id="T_edc6e_row7_col2" class="data row7 col2" >$266</td>
#       <td id="T_edc6e_row7_col3" class="data row7 col3" >$0</td>
#       <td id="T_edc6e_row7_col4" class="data row7 col4" >$0</td>
#       <td id="T_edc6e_row7_col5" class="data row7 col5" >$0</td>
#     </

# %% [markdown]
# ## Multiple interest rates

# %%
table, list_mortgages = table_multiple_interest_rates(
    sale_price=750000, 
    down_payment_percent=20,
    interest_rates=[0.0225, 0.0250, 0.0275, 0.03, 0.0325, 0.0350]
)
table
# Out:
# <style type="text/css">
# #T_0930d_ tbody {
#   border: solid thin #ddd;
# }
# #T_0930d_ thead {
#   border: solid thin #ddd;
# }
# #T_0930d_row0_col0, #T_0930d_row0_col1, #T_0930d_row0_col2, #T_0930d_row0_col3, #T_0930d_row0_col4, #T_0930d_row0_col5, #T_0930d_row1_col0, #T_0930d_row2_col0, #T_0930d_row2_col1, #T_0930d_row2_col2, #T_0930d_row2_col3, #T_0930d_row2_col4, #T_0930d_row2_col5, #T_0930d_row3_col0, #T_0930d_row3_col1, #T_0930d_row3_col2, #T_0930d_row3_col3, #T_0930d_row3_col4, #T_0930d_row3_col5, #T_0930d_row4_col0, #T_0930d_row4_col1, #T_0930d_row4_col2, #T_0930d_row4_col3, #T_0930d_row4_col4, #T_0930d_row4_col5, #T_0930d_row5_col0, #T_0930d_row5_col1, #T_0930d_row5_col2, #T_0930d_row5_col3, #T_0930d_row5_col4, #T_0930d_row5_col5, #T_0930d_row6_col0, #T_0930d_row7_col0, #T_0930d_row7_col1, #T_0930d_row7_col2, #T_0930d_row7_col3, #T_0930d_row7_col4, #T_0930d_row7_col5, #T_0930d_row8_col0, #T_0930d_row9_col0, #T_0930d_row10_col0, #T_0930d_row11_col0, #T_0930d_row11_col1, #T_0930d_row11_col2, #T_0930d_row11_col3, #T_0930d_row11_col4, #T_0930d_row11_col5, #T_0930d_row12_col0, #T_0930d_row13_col0, #T_0930d_row14_col0, #T_0930d_row14_col1, #T_0930d_row14_col2, #T_0930d_row14_col3, #T_0930d_row14_col4, #T_0930d_row14_col5, #T_0930d_row15_col0, #T_0930d_row16_col0 {
#   font-weight: bold;
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_0930d_row1_col1 {
#   font-weight: bold;
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_0930d_row1_col2 {
#   font-weight: bold;
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_0930d_row1_col3 {
#   font-weight: bold;
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_0930d_row1_col4 {
#   font-weight: bold;
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_0930d_row1_col5, #T_0930d_row6_col5, #T_0930d_row8_col5, #T_0930d_row9_col5, #T_0930d_row10_col5, #T_0930d_row12_col5, #T_0930d_row13_col5, #T_0930d_row15_col5, #T_0930d_row16_col5 {
#   font-weight: bold;
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_0930d_row6_col1 {
#   font-weight: bold;
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_0930d_row6_col2 {
#   font-weight: bold;
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_0930d_row6_col3 {
#   font-weight: bold;
#   background-color: #f34a36;
#   color: #f1f1f1;
# }
# #T_0930d_row6_col4, #T_0930d_row8_col4, #T_0930d_row9_col4, #T_0930d_row10_col4, #T_0930d_row12_col4, #T_0930d_row13_col4, #T_0930d_row15_col4, #T_0930d_row16_col4 {
#   font-weight: bold;
#   background-color: #be151a;
#   color: #f1f1f1;
# }
# #T_0930d_row8_col1, #T_0930d_row9_col1, #T_0930d_row10_col1, #T_0930d_row12_col1, #T_0930d_row13_col1, #T_0930d_row15_col1, #T_0930d_row16_col1 {
#   font-weight: bold;
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_0930d_row8_col2, #T_0930d_row9_col2, #T_0930d_row10_col2, #T_0930d_row12_col2, #T_0930d_row13_col2, #T_0930d_row15_col2, #T_0930d_row16_col2 {
#   font-weight: bold;
#   background-color: #fc8e6e;
#   color: #000000;
# }
# #T_0930d_row8_col3, #T_0930d_row9_col3, #T_0930d_row10_col3, #T_0930d_row12_col3, #T_0930d_row13_col3, #T_0930d_row15_col3, #T_0930d_row16_col3 {
#   font-weight: bold;
#   background-color: #f34935;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0930d_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Interest Rate</th>
#       <th class="col_heading level0 col0" >2.25%</th>
#       <th class="col_heading level0 col1" >2.50%</th>
#       <th class="col_heading level0 col2" >2.75%</th>
#       <th class="col_heading level0 col3" >3.00%</th>
#       <th class="col_heading level0 col4" >3.25%</th>
#       <th class="col_heading level0 col5" >3.50%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0930d_level0_row0" class="row_heading level0 row0" >Down Payment Fraction</th>
#       <td id="T_0930d_row0_col0" class="data row0 col0" >0.200000</td>
#       <td id="T_0930d_row0_col1" class="data row0 col1" >0.200000</td>
#       <td id="T_0930d_row0_col2" class="data row0 col2" >0.200000</td>
#       <td id="T_0930d_row0_col3" class="data row0 col3" >0.200000</td>
#       <td id="T_0930d_row0_col4" class="data row0 col4" >0.200000</td>
#       <td id="T_0930d_row0_col5" class="data row0 col5" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_0930d_level0_row1" class="row_heading level0 row1" >Interest Rate</th>
#       <td id="T_0930d_row1_col0" class="data row1 col0" >0.022500</td>
#       <td id="T_0930d_row1_col1" class="data row1 col1" >0.025000</td>
#       <td id="T_0930d_row1_col2" class="data row1 col2" >0.027500</td>
#       <td id="T_0930d_row1_col3" class="data row1 col3" >0.030000</td>
#       <td id="T_0930d_row1_col4" class="data row1 col4" >0.032500</td>
#       <td id="T_0930d_row1_col5" class="data row1 col5" >0.035000</td>
#     </tr>
#     <tr>
#       <th id="T_0930d_level0_row2" class="row_heading level0 row2" >PMI Rate</th>
#       <td id="T_0930d_row2_col0" class="data row2 col0" >0.5%</td>
#       <td id="T_0930d_row2_col1" class="data row2 col1" >0.5%</td>
#       <td id="T_0930d_row2_col2" class="data row2 col2" >0.5%</td>
#       <td id="T_0930d_row2_col3" class="data row2 col3" >0.5%</td>
#       <td id="T_0930d_row2_col4" class="data row2 col4" >0.5%</td>
#       <td id="T_0930d_row2_col5" class="data row2 col5" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_0930d_level0_row3" class="row_heading level0 row3" >Sale Price</th>
#       <td id="T_0930d_row3_col0" class="data row3 col0" >$750,000</td>
#       <td id="T_0930d_row3_col1" class="data row3 col1" >$750,000</td>
#       <td id="T_0930d_row3_col2" class="data row3 col2" >$750,000</td>
#       <td id="T_0930d_row3_col3" class="data row3 col3" >$750,000</td>
#       <td id="T_0930d_row3_col4" class="data row3 col4" >$750,000</td>
#       <td id="T_0930d_row3_col5" class="data row3 col5" >$750,000</td>
#     </tr>
#     <tr>
#       <th id="T_0930d_level0_row4" class="row_heading level0 row4" >Down Payment</th>
#       <td id="T_0930d_row4_col0" class="data row4 col0" >$150,000</td>
#       <td id="T_0930d_row4_col1" class="data row4 col1" >$150,000</td>
#       <td id="T_0930d_row4_col2" class="data row4 col2" >$150,000</td>
#       <td id="T_0930d_row4_col3" class="data row4 col3" >$150,000</td>
#       <td id="T_0930d_row4_col4" class="data row4 col4" >$150,000</td>
#       <td id="T_0930d_row4_col5" class="data row4 col5" >$150,000</td>
#     </tr>
#     <tr>
#       <th id="T_0930d_level0_row5" class="row_heading level0 row5" >Principal loan</th>
#       <td id="T_0930d_row5_col0" class="data row5 col0" >$600,000</td>
#       <td id="T_0930d_row5_col1" class="data row5 col1" >$600,000</td>
#       <td id="T_0930d_row5_col2" class="data row5 col2" >$600,000</td>
#       <td id="T_0930d_row5_col3" class="data row5 col3" >$600,000</td>
#       <td id="T_0930d_row5_col4" class="data row5 col4" >$600,000</td>
#       <td id="T_0930d_row5_col5" class="data row5 col5" >$600,000</td>
#     </tr>
#     <tr>
#       <th id="T_0930d_level0_row6" class="row_heading level0 row6" >Interest to Principal Ratio</th>
#       <td id="T_0930d_row6_col0" class="data row6 col0" >0.380</td>
#       <td id="T_0930d_row6_col1" class="data row6 col1" >0.420</td>
#       <td id="T_0930d_row6_col2" class="data row6 col2" >0.470</td>
#       <td id="T_0930d_row6_col3" class="data row6 col3" >0.520</td>
#       <td id="T_0930d_row6_col4" class="data row6 col4" >0.570</td>
#       <td id="T_0930d_row6_col5" class="data row6 col5" >0.620</td>
#     </tr>
#     <tr>
#       <th id="T_0930d_level0_row7" class="row_heading level0 row7" >Monthly PMI Insurance</th>
#       <td id="T_0930d_row7_col0" class="data row7 col0" >$0</td>
#       <td id="T_0930d_row7_col1" class="data row7 col1" >$0</td>
#       <td id="T_0930d_row7_col2" class="data row7 col2" >$0</td>
#       <td id="T_0930d_row7_col3" class="data row7 col3" >$0</td>
#       <td id="T_0930d_row7_col4" class="data row7 col4" >$0</td>
#       <td id="T_0930d_row7_col5" class="data row7 col5" >$0</td>
#     </tr>
#     <tr>
#       <th id="T_0930d_level0_row8" class="row_heading level0 row8" >Monthly Principal + Interest</th>
#       <td id="T_0930d_row8_col0" class="data row8 col0" >$2,293</td>
#       <td id="T_0930d_row8_col1" cla

# %% [markdown]
# # Single Mortgage

# %%
mortgage = Mortgage(
    sale_price = 575000,
    num_years = 30,
    interest_rate = 0.0375,
    down_payment_fraction = 0.1
)
mortgage.summary()
# Out:
# <style type="text/css">
# #T_6db1e_ tbody {
#   border: solid thin #ddd;
# }
# #T_6db1e_ thead {
#   border: solid thin #ddd;
# }
# #T_6db1e_row0_col0, #T_6db1e_row1_col0, #T_6db1e_row2_col0, #T_6db1e_row3_col0, #T_6db1e_row4_col0, #T_6db1e_row5_col0, #T_6db1e_row6_col0, #T_6db1e_row7_col0, #T_6db1e_row8_col0, #T_6db1e_row9_col0, #T_6db1e_row10_col0, #T_6db1e_row11_col0, #T_6db1e_row12_col0, #T_6db1e_row13_col0, #T_6db1e_row14_col0, #T_6db1e_row15_col0, #T_6db1e_row16_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_6db1e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6db1e_level0_row0" class="row_heading level0 row0" >Down Payment Fraction</th>
#       <td id="T_6db1e_row0_col0" class="data row0 col0" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row1" class="row_heading level0 row1" >Interest Rate</th>
#       <td id="T_6db1e_row1_col0" class="data row1 col0" >0.037500</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row2" class="row_heading level0 row2" >PMI Rate</th>
#       <td id="T_6db1e_row2_col0" class="data row2 col0" >1.0%</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row3" class="row_heading level0 row3" >Sale Price</th>
#       <td id="T_6db1e_row3_col0" class="data row3 col0" >$575,000</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row4" class="row_heading level0 row4" >Down Payment</th>
#       <td id="T_6db1e_row4_col0" class="data row4 col0" >$57,500</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row5" class="row_heading level0 row5" >Principal loan</th>
#       <td id="T_6db1e_row5_col0" class="data row5 col0" >$517,500</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row6" class="row_heading level0 row6" >Interest to Principal Ratio</th>
#       <td id="T_6db1e_row6_col0" class="data row6 col0" >0.670</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row7" class="row_heading level0 row7" >Monthly PMI Insurance</th>
#       <td id="T_6db1e_row7_col0" class="data row7 col0" >$431</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row8" class="row_heading level0 row8" >Monthly Principal + Interest</th>
#       <td id="T_6db1e_row8_col0" class="data row8 col0" >$2,397</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row9" class="row_heading level0 row9" >Monthly loan Payment</th>
#       <td id="T_6db1e_row9_col0" class="data row9 col0" >$2,828</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row10" class="row_heading level0 row10" >Monthly Payment + Tax (approx)</th>
#       <td id="T_6db1e_row10_col0" class="data row10 col0" >$3,499</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row11" class="row_heading level0 row11" >Total Tax Paid*</th>
#       <td id="T_6db1e_row11_col0" class="data row11 col0" >$241,500</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row12" class="row_heading level0 row12" >Total loan Payment</th>
#       <td id="T_6db1e_row12_col0" class="data row12 col0" >$862,784</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row13" class="row_heading level0 row13" >Total Interest Paid</th>
#       <td id="T_6db1e_row13_col0" class="data row13 col0" >$345,284</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row14" class="row_heading level0 row14" >Total PMI Paid*</th>
#       <td id="T_6db1e_row14_col0" class="data row14 col0" >$48,300</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row15" class="row_heading level0 row15" >Total Cost (no tax)</th>
#       <td id="T_6db1e_row15_col0" class="data row15 col0" >$968,584</td>
#     </tr>
#     <tr>
#       <th id="T_6db1e_level0_row16" class="row_heading level0 row16" >Grand Total</th>
#       <td id="T_6db1e_row16_col0" class="data row16 col0" >$1,210,084</td>
#     </tr>
#   </tbody>
# </table>

# %%
mortgage.plot()
